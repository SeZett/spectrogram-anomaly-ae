# %% [markdown]
# # Autoencoder Training
#
# This notebook trains a convolutional autoencoder on **normal data** (no chatter).
# The model learns a compact representation and attempts to reconstruct the input images.
# Because anomalous samples (chatter) are not seen during training, we expect them to yield a **higher reconstruction error**.
#
# **Core idea:** anomaly score = reconstruction error (e.g., MSE) between the input and its reconstruction.

# %%
import os
import random
import numpy as np
import pandas as pd
import tensorflow as tf
from PIL import Image
from tqdm import tqdm
import plotly.express as px 
import os
from pathlib import Path
from collections import defaultdict

from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, UpSampling2D
from tensorflow.keras.layers import Dense, Flatten, Reshape
import matplotlib.pyplot as plt
from tensorflow.keras.callbacks import EarlyStopping

# %%
# =========================
# Reproducibility (Seeds)
# =========================
SEED = 42

os.environ["PYTHONHASHSEED"] = str(SEED)
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

# =========================
# GPU check (optional)
# =========================
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    print(f"TensorFlow detects {len(gpus)} GPU(s):")
    for gpu in gpus:
        print("-", gpu)
else:
    print("No GPU found.")
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# No GPU found.

# %% [markdown]
# ## Data
#
# The spectrograms are loaded as images.
#
# We distinguish between:
# - **GOOD / Normal**: samples without chatter (used for training)
# - **BAD / Chatter**: potentially anomalous samples (typically used for evaluation)
#
# This notebook trains the autoencoder using **only the normal (GOOD)** class.

# %%
def extract_file_id(path):
    return Path(path).stem.split("_seg")[0]

# %%
TEST_SIZE = 0.2 # percentage
VAL_SIZE = 0.3   # percentage
SEED = 42
MIN_FILES = 5    # Min. files for splitting

DATA_ROOT = Path("../../data/04_bosch_dataset/M01/OP07") #only Machine 1 samples

# Collect all GOOD / BADimages
GOOD_PATHS = list((DATA_ROOT / "good").rglob("*.png"))
BAD_PATHS = list((DATA_ROOT / "bad").rglob("*.png"))

file_to_paths = defaultdict(list)

for p in GOOD_PATHS:
    fid = extract_file_id(p)
    file_to_paths[fid].append(p)

# Good-File splitting

file_ids = list(file_to_paths.keys())
n_files = len(file_ids)

if n_files < MIN_FILES:
    raise ValueError(f"Zu wenige GOOD-Dateien: {n_files}")

# Erst Train vs Temp (Val+Test)
train_files, temp_files = train_test_split(
    file_ids,
    test_size=TEST_SIZE + VAL_SIZE,
    random_state=SEED,
    shuffle=True
)

# Anteil Test relativ zu temp berechnen
relative_test_size = TEST_SIZE / (TEST_SIZE + VAL_SIZE)

val_files, test_files = train_test_split(
    temp_files,
    test_size=relative_test_size,
    random_state=SEED,
    shuffle=True
)

print(f"GOOD split -> Train: {len(train_files)}, Val: {len(val_files)}, Test: {len(test_files)}")
#-------------------------------------

# Val
val_files, test_files = train_test_split(
    temp_files,
    test_size=7,
    random_state=SEED,
    shuffle=True
)

# bad files
bad_file_to_paths = defaultdict(list)

for p in BAD_PATHS:
    fid = extract_file_id(p)
    bad_file_to_paths[fid].append(p)


bad_file_ids = list(bad_file_to_paths.keys())
n_bad = len(bad_file_ids)

if n_bad < 3:
    print(f"Warnung: Sehr wenige BAD-Dateien ({n_bad}), Split wird angepasst")

# Prozentual splitten, aber mindestens 1 Sample sicherstellen
bad_test_size = max(1, int(TEST_SIZE * n_bad))
bad_val_size = max(1, int(VAL_SIZE * n_bad))

# Sicherstellen, dass genug übrig bleibt
if bad_test_size + bad_val_size >= n_bad:
    bad_test_size = max(1, n_bad // 3)
    bad_val_size = max(1, n_bad // 3)

# Split durchführen
bad_temp, bad_test_files = train_test_split(
    bad_file_ids,
    test_size=bad_test_size,
    random_state=SEED,
    shuffle=True
)

bad_val_files, _ = train_test_split(
    bad_temp,
    test_size=bad_val_size,
    random_state=SEED,
    shuffle=True
)

print(f"BAD split -> Val: {len(bad_val_files)}, Test: {len(bad_test_files)}")
# Out:
# GOOD split -> Train: 21, Val: 13, Test: 9
# BAD split -> Val: 2, Test: 1

# %%
train_paths = []
for f in train_files:
    train_paths.extend(file_to_paths[f])

val_paths = []

# GOOD
for f in val_files:
    val_paths.extend(file_to_paths[f])

# BAD (WICHTIG → nur bad_val_files!)
for f in bad_val_files:
    val_paths.extend(bad_file_to_paths[f])

test_paths = []

# GOOD
for f in test_files:
    test_paths.extend(file_to_paths[f])

# BAD
for f in bad_test_files:
    test_paths.extend(bad_file_to_paths[f])

#-------------------------

y_val = []

for p in val_paths:
    if "good" in p.parts:
        y_val.append(0)
    elif "bad" in p.parts:
        y_val.append(1)
    else:
        raise ValueError(f"Unknown label in path: {p}")


y_test = []

for p in test_paths:
    if "good" in p.parts:
        y_test.append(0)
    elif "bad" in p.parts:
        y_test.append(1)
    else:
        raise ValueError(f"Unknown label in path: {p}")


print("Train segments:", len(train_paths))
print("Val segments:", len(val_paths))
print("Test segments:", len(test_paths))

print("\nVal labels:")
print(pd.Series(y_val).value_counts())

print("\nTest labels:")
print(pd.Series(y_test).value_counts())
# Out:
# Train segments: 96
# Val segments: 82
# Test segments: 36
#
# Val labels:
# 0    75
# 1     7
# Name: count, dtype: int64
#
# Test labels:
# 0    32
# 1     4
# Name: count, dtype: int64

# %%
def load_images(paths, target_size=(150, 100)):
    images = []

    for path in tqdm(paths):
        img = Image.open(path).convert("RGB").resize(target_size)
        images.append(np.array(img))

    return np.array(images)

# %% [markdown]
# Load only normal data!

# %%
x_train = load_images(train_paths)
x_val = load_images(val_paths) 
x_test = load_images(test_paths)

x_train = x_train.astype("float32") / 255.0
x_val = x_val.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0


print("Train segments:", x_train.shape)
print("Val segments:", x_val.shape)
print("Test segments:", x_test.shape)

print("Train files:", len(train_files))
print("Val files:", len(val_files))
print("Test files:", len(test_files))
# Out:
# 100%|██████████| 96/96 [00:05<00:00, 17.88it/s]
# 100%|██████████| 82/82 [00:04<00:00, 17.29it/s]
# 100%|██████████| 36/36 [00:02<00:00, 17.17it/s]
# Train segments: (96, 100, 150, 3)
# Val segments: (82, 100, 150, 3)
# Test segments: (36, 100, 150, 3)
# Train files: 21
# Val files: 15
# Test files: 7

# %% [markdown]
# ## Visualization / Sanity Check
#
# To verify the data pipeline, we visualize one example spectrogram from the training set.
# This helps confirm that resizing and normalization behave as expected.

# %%
fig = px.imshow(x_train[11])
fig.update_layout(coloraxis_showscale=False)
fig.show()

# %% [markdown]
# ## Model: Convolutional Autoencoder
#
# The autoencoder consists of three parts:
#
# 1. **Encoder**: extracts features using convolutions and progressively reduces spatial dimensions
# 2. **Bottleneck**: compresses the representation using a dense layer
# 3. **Decoder**: reconstructs the input via dense expansion, reshaping, upsampling, and convolutions
#
# ### Training objective
# The model minimizes the reconstruction error (MSE) between the input image $x$ and its reconstruction $\hat{x}$.
#
# During anomaly detection, the reconstruction error is used as an anomaly score.

# %%
input_shape = (100, 150, 3)

# Sequential-Modell
autoencoder = Sequential()

# ---- Encoder ----
autoencoder.add(Conv2D(8, (3, 3), activation='relu', padding='same', input_shape=input_shape))
autoencoder.add(MaxPooling2D((2, 2), padding='same'))  

autoencoder.add(Conv2D(16, (3, 3), activation='relu', padding='same'))  
autoencoder.add(MaxPooling2D((2, 3), padding='same')) 

#autoencoder.add(Conv2D(32, (3, 3), activation='relu', padding='same')) 

# ---- Bottleneck ----
autoencoder.add(Flatten()) 
autoencoder.add(Dense(16, activation='relu'))  # compact latent representation

# ---- Decoder ----
autoencoder.add(Dense(25 * 25 * 16, activation='relu'))  
autoencoder.add(Reshape((25, 25, 16)))  
autoencoder.add(Conv2D(16, (3, 3), activation='relu', padding='same')) 

autoencoder.add(UpSampling2D((2, 3)))  
autoencoder.add(Conv2D(8, (3, 3), activation='relu', padding='same')) 

autoencoder.add(UpSampling2D((2, 2))) 
#autoencoder.add(Conv2D(8, (3, 3), activation='relu', padding='same'))

autoencoder.add(Conv2D(3, (3, 3), activation='sigmoid', padding='same'))
# Out:
# c:\Users\Zeleny\Documents\01_VSCode\spectrogram-anomaly-ae\.spectro-ae-venv\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# ## Training Setup
#
# - **Optimizer:** Adam with a small learning rate
# - **Loss:** Mean Squared Error (MSE), measuring reconstruction quality
#
# Because the autoencoder is trained on normal data only, anomalous inputs are expected to produce larger reconstruction errors.

# %%
autoencoder.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss='mse'
)

autoencoder.summary()

#---
# early Stopping Callback
#-------------------------

early_stop = EarlyStopping(
    monitor="val_loss",
    patience=10,
    restore_best_weights=True
)


history = autoencoder.fit(
    x_train, x_train,
    epochs=2000,
    batch_size=32,
    validation_data=(x_val, x_val),
    shuffle=True,
    callbacks=[early_stop]
)
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 100, 150, 8)    │           224 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 50, 75, 8)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 50, 75, 16)     │         1,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 25, 25, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 10000)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 16)             │       160,016 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10000)          │       170,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape (Reshape)               │ (None, 25, 25, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 25, 25, 16)     │         2,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d (UpSampling2D)    │ (None, 50, 75, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 50, 75, 8)      │         1,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_1 (UpSampling2D)  │ (None, 100, 150, 8)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 100, 150, 3)    │           219 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 335,107 (1.28 MB)
#  Trainable params: 335,107 (1.28 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - loss: 0.2055 - val_loss: 0.1998
# Epoch 2/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.2049 - val_loss: 0.1990
# Epoch 3/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.2041 - val_loss: 0.1980
# Epoch 4/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.2030 - val_loss: 0.1967
# Epoch 5/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.2015 - val_loss: 0.1950
# Epoch 6/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.1996 - val_loss: 0.1928
# Epoch 7/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.1972 - val_loss: 0.1901
# Epoch 8/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.1942 - val_loss: 0.1866
# Epoch 9/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1904 - val_loss: 0.1823
# Epoch 10/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.1857 - val_loss: 0.1770
# Epoch 11/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - loss: 0.1800 - val_loss: 0.1707
# Epoch 12/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - loss: 0.1732 - val_loss: 0.1632
# Epoch 13/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.1652 - val_loss: 0.1546
# Epoch 14/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 0.1560 - val_loss: 0.1450
# Epoch 15/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - loss: 0.1458 - val_loss: 0.1344
# Epoch 16/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.1346 - val_loss: 0.1229
# Epoch 17/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.1227 - val_loss: 0.1109
# Epoch 18/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.1102 - val_loss: 0.0986
# Epoch 19/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0974 - val_loss: 0.0860
# Epoch 20/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0844 - val_loss: 0.0736
# Epoch 21/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.0716 - val_loss: 0.0615
# Epoch 22/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.0593 - val_loss: 0.0502
# Epoch 23/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.0480 - val_loss: 0.0402
# Epoch 24/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0381 - val_loss: 0.0319
# Epoch 25/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 0.0299 - val_loss: 0.0255
# Epoch 26/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - loss: 0.0238 - val_loss: 0.0210
# Epoch 27/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0194 - val_loss: 0.0179
# Epoch 28/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0164 - val_loss: 0.0159
# Epoch 29/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.0145 - val_loss: 0.0147
# Epoch 30/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 0.0133 - val_loss: 0.0140
# Epoch 31/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0125 - val_loss: 0.0135
# Epoch 32/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0120 - val_loss: 0.0132
# Epoch 33/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.0117 - val_loss: 0.0130
# Epoch 34/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0115 - val_loss: 0.0128
# Epoch 35/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.0113 - val_loss: 0.0127
# Epoch 36/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.0111 - val_loss: 0.0126
# Epoch 37/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0110 - val_loss: 0.0125
# Epoch 38/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.0109 - val_loss: 0.0124
# Epoch 39/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0108 - val_loss: 0.0123
# Epoch 40/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0107 - val_loss: 0.0123
# Epoch 41/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0106 - val_loss: 0.0122
# Epoch 42/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0105 - val_loss: 0.0121
# Epoch 43/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0105 - val_loss: 0.0121
# Epoch 44/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0104 - val_loss: 0.0120
# Epoch 45/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0103 - val_loss: 0.0119
# Epoch 46/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0102 - val_loss: 0.0119
# Epoch 47/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0102 - val_loss: 0.0118
# Epoch 48/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0101 - val_loss: 0.0118
# Epoch 49/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0100 - val_loss: 0.0117
# Epoch 50/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0100 - val_loss: 0.0117
# Epoch 51/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0099 - val_loss: 0.0116
# Epoch 52/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0098 - val_loss: 0.0115
# Epoch 53/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0098 - val_loss: 0.0115
# Epoch 54/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0097 - val_loss: 0.0114
# Epoch 55/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0097 - val_loss: 0.0114
# Epoch 56/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.0096 - val_loss: 0.0113
# Epoch 57/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0095 - val_loss: 0.0113
# Epoch 58/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0095 - val_loss: 0.0112
# Epoch 59/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0094 - val_loss: 0.0112
# Epoch 60/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0094 - val_loss: 0.0111
# Epoch 61/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0093 - val_loss: 0.0111
# Epoch 62/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0093 - val_loss: 0.0111
# Epoch 63/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0092 - val_loss: 0.0110
# Epoch 64/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0092 - val_loss: 0.0110
# Epoch 65/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0091 - val_loss: 0.0109
# Epoch 66/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0091 - val_loss: 0.0109
# Epoch 67/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0090 - val_loss: 0.0109
# Epoch 68/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0090 - val_loss: 0.0108
# Epoch 69/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0089 - val_loss: 0.0108
# Epoch 70/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0089 - val_loss: 0.0107
# Epoch 71/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0088 - val_loss: 0.0107
# Epoch 72/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.0088 - val_loss: 0.0107
# Epoch 73/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.0087 - val_loss: 0.0106
# Epoch 74/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0087 - val_loss: 0.0106
# Epoch 75/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.0087 - val_loss: 0.0105
# Epoch 76/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.0086 - val_loss: 0.0105
# Epoch 77/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0086 - val_loss: 0.0105
# Epoch 78/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0085 - val_loss: 0.0104
# Epoch 79/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0085 - val_loss: 0.0104
# Epoch 80/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0084 - val_loss: 0.0104
# Epoch 81/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0084 - val_loss: 0.0103
# Epoch 82/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0084 - val_loss: 0.0103
# Epoch 83/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0083 - val_loss: 0.0102
# Epoch 84/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.0083 - val_loss: 0.0102
# Epoch 85/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0082 - val_loss: 0.0102
# Epoch 86/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.0082 - val_loss: 0.0101
# Epoch 87/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0082 - val_loss: 0.0101
# Epoch 88/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0081 - val_loss: 0.0101
# Epoch 89/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0081 - val_loss: 0.0100
# Epoch 90/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0080 - val_loss: 0.0100
# Epoch 91/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0080 - val_loss: 0.0099
# Epoch 92/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0080 - val_loss: 0.0099
# Epoch 93/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0079 - val_loss: 0.0099
# Epoch 94/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0079 - val_loss: 0.0098
# Epoch 95/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0079 - val_loss: 0.0098
# Epoch 96/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0078 - val_loss: 0.0098
# Epoch 97/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0078 - val_loss: 0.0098
# Epoch 98/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0078 - val_loss: 0.0097
# Epoch 99/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0077 - val_loss: 0.0097
# Epoch 100/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0077 - val_loss: 0.0097
# Epoch 101/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0077 - val_loss: 0.0096
# Epoch 102/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0076 - val_loss: 0.0096
# Epoch 103/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0076 - val_loss: 0.0096
# Epoch 104/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0076 - val_loss: 0.0096
# Epoch 105/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0076 - val_loss: 0.0095
# Epoch 106/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0075 - val_loss: 0.0095
# Epoch 107/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.0075 - val_loss: 0.0095
# Epoch 108/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0075 - val_loss: 0.0095
# Epoch 109/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.0075 - val_loss: 0.0094
# Epoch 110/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0074 - val_loss: 0.0094
# Epoch 111/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.0074 - val_loss: 0.0094
# Epoch 112/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0074 - val_loss: 0.0094
# Epoch 113/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0074 - val_loss: 0.0094
# Epoch 114/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0074 - val_loss: 0.0093
# Epoch 115/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0073 - val_loss: 0.0093
# Epoch 116/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0073 - val_loss: 0.0093
# Epoch 117/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0073 - val_loss: 0.0093
# Epoch 118/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.0073 - val_loss: 0.0093
# Epoch 119/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0073 - val_loss: 0.0092
# Epoch 120/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0072 - val_loss: 0.0092
# Epoch 121/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0072 - val_loss: 0.0092
# Epoch 122/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0072 - val_loss: 0.0092
# Epoch 123/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0072 - val_loss: 0.0092
# Epoch 124/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.0072 - val_loss: 0.0092
# Epoch 125/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0071 - val_loss: 0.0091
# Epoch 126/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.0071 - val_loss: 0.0091
# Epoch 127/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.0071 - val_loss: 0.0091
# Epoch 128/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.0071 - val_loss: 0.0091
# Epoch 129/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0071 - val_loss: 0.0091
# Epoch 130/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0071 - val_loss: 0.0091
# Epoch 131/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.0070 - val_loss: 0.0090
# Epoch 132/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0070 - val_loss: 0.0090
# Epoch 133/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0070 - val_loss: 0.0090
# Epoch 134/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0070 - val_loss: 0.0090
# Epoch 135/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0070 - val_loss: 0.0090
# Epoch 136/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0070 - val_loss: 0.0090
# Epoch 137/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.0070 - val_loss: 0.0090
# Epoch 138/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - loss: 0.0069 - val_loss: 0.0089
# Epoch 139/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0069 - val_loss: 0.0089
# Epoch 140/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0069 - val_loss: 0.0089
# Epoch 141/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0069 - val_loss: 0.0089
# Epoch 142/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.0069 - val_loss: 0.0089
# Epoch 143/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 0.0069 - val_loss: 0.0089
# Epoch 144/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0069 - val_loss: 0.0089
# Epoch 145/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0069 - val_loss: 0.0089
# Epoch 146/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - loss: 0.0068 - val_loss: 0.0088
# Epoch 147/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.0068 - val_loss: 0.0088
# Epoch 148/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0068 - val_loss: 0.0088
# Epoch 149/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0068 - val_loss: 0.0088
# Epoch 150/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0068 - val_loss: 0.0088
# Epoch 151/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0068 - val_loss: 0.0088
# Epoch 152/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0068 - val_loss: 0.0088
# Epoch 153/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0068 - val_loss: 0.0088
# Epoch 154/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0068 - val_loss: 0.0087
# Epoch 155/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0067 - val_loss: 0.0087
# Epoch 156/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0067 - val_loss: 0.0087
# Epoch 157/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0067 - val_loss: 0.0087
# Epoch 158/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0067 - val_loss: 0.0087
# Epoch 159/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0067 - val_loss: 0.0087
# Epoch 160/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0067 - val_loss: 0.0087
# Epoch 161/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0067 - val_loss: 0.0087
# Epoch 162/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0067 - val_loss: 0.0087
# Epoch 163/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0067 - val_loss: 0.0087
# Epoch 164/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 0.0067 - val_loss: 0.0087
# Epoch 165/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0066 - val_loss: 0.0086
# Epoch 166/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0066 - val_loss: 0.0086
# Epoch 167/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0066 - val_loss: 0.0086
# Epoch 168/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - loss: 0.0066 - val_loss: 0.0086
# Epoch 169/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0066 - val_loss: 0.0086
# Epoch 170/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0066 - val_loss: 0.0086
# Epoch 171/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0066 - val_loss: 0.0086
# Epoch 172/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0066 - val_loss: 0.0086
# Epoch 173/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0066 - val_loss: 0.0086
# Epoch 174/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0066 - val_loss: 0.0086
# Epoch 175/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.0066 - val_loss: 0.0086
# Epoch 176/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0066 - val_loss: 0.0085
# Epoch 177/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0065 - val_loss: 0.0085
# Epoch 178/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.0065 - val_loss: 0.0085
# Epoch 179/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0065 - val_loss: 0.0085
# Epoch 180/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0065 - val_loss: 0.0085
# Epoch 181/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0065 - val_loss: 0.0085
# Epoch 182/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0065 - val_loss: 0.0085
# Epoch 183/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0065 - val_loss: 0.0085
# Epoch 184/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0065 - val_loss: 0.0085
# Epoch 185/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - loss: 0.0065 - val_loss: 0.0085
# Epoch 186/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0065 - val_loss: 0.0085
# Epoch 187/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0065 - val_loss: 0.0085
# Epoch 188/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0065 - val_loss: 0.0085
# Epoch 189/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0065 - val_loss: 0.0084
# Epoch 190/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0065 - val_loss: 0.0084
# Epoch 191/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.0064 - val_loss: 0.0084
# Epoch 192/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0064 - val_loss: 0.0084
# Epoch 193/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.0064 - val_loss: 0.0084
# Epoch 194/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0064 - val_loss: 0.0084
# Epoch 195/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0064 - val_loss: 0.0084
# Epoch 196/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0064 - val_loss: 0.0084
# Epoch 197/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0064 - val_loss: 0.0084
# Epoch 198/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0064 - val_loss: 0.0084
# Epoch 199/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.0064 - val_loss: 0.0084
# Epoch 200/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0064 - val_loss: 0.0084
# Epoch 201/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0064 - val_loss: 0.0084
# Epoch 202/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0064 - val_loss: 0.0084
# Epoch 203/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0064 - val_loss: 0.0084
# Epoch 204/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0064 - val_loss: 0.0084
# Epoch 205/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0064 - val_loss: 0.0084
# Epoch 206/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0064 - val_loss: 0.0083
# Epoch 207/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0064 - val_loss: 0.0083
# Epoch 208/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0063 - val_loss: 0.0083
# Epoch 209/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0063 - val_loss: 0.0083
# Epoch 210/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0063 - val_loss: 0.0083
# Epoch 211/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0063 - val_loss: 0.0083
# Epoch 212/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0063 - val_loss: 0.0083
# Epoch 213/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0063 - val_loss: 0.0083
# Epoch 214/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0063 - val_loss: 0.0083
# Epoch 215/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0063 - val_loss: 0.0083
# Epoch 216/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0063 - val_loss: 0.0083
# Epoch 217/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0063 - val_loss: 0.0083
# Epoch 218/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0063 - val_loss: 0.0083
# Epoch 219/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0063 - val_loss: 0.0083
# Epoch 220/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0063 - val_loss: 0.0083
# Epoch 221/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0063 - val_loss: 0.0083
# Epoch 222/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0063 - val_loss: 0.0083
# Epoch 223/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0063 - val_loss: 0.0083
# Epoch 224/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0063 - val_loss: 0.0082
# Epoch 225/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.0063 - val_loss: 0.0082
# Epoch 226/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.0063 - val_loss: 0.0082
# Epoch 227/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0063 - val_loss: 0.0082
# Epoch 228/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0062 - val_loss: 0.0082
# Epoch 229/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0062 - val_loss: 0.0082
# Epoch 230/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0062 - val_loss: 0.0082
# Epoch 231/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0062 - val_loss: 0.0082
# Epoch 232/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0062 - val_loss: 0.0082
# Epoch 233/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0062 - val_loss: 0.0082
# Epoch 234/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0062 - val_loss: 0.0082
# Epoch 235/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0062 - val_loss: 0.0082
# Epoch 236/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0062 - val_loss: 0.0082
# Epoch 237/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0062 - val_loss: 0.0082
# Epoch 238/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0062 - val_loss: 0.0082
# Epoch 239/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0062 - val_loss: 0.0082
# Epoch 240/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0062 - val_loss: 0.0082
# Epoch 241/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0062 - val_loss: 0.0082
# Epoch 242/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0062 - val_loss: 0.0082
# Epoch 243/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0062 - val_loss: 0.0082
# Epoch 244/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0062 - val_loss: 0.0082
# Epoch 245/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0062 - val_loss: 0.0082
# Epoch 246/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0062 - val_loss: 0.0081
# Epoch 247/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0062 - val_loss: 0.0081
# Epoch 248/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0062 - val_loss: 0.0081
# Epoch 249/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.0062 - val_loss: 0.0081
# Epoch 250/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0062 - val_loss: 0.0081
# Epoch 251/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0061 - val_loss: 0.0081
# Epoch 252/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0061 - val_loss: 0.0081
# Epoch 253/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0061 - val_loss: 0.0081
# Epoch 254/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0061 - val_loss: 0.0081
# Epoch 255/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0061 - val_loss: 0.0081
# Epoch 256/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0061 - val_loss: 0.0081
# Epoch 257/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0061 - val_loss: 0.0081
# Epoch 258/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0061 - val_loss: 0.0081
# Epoch 259/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0061 - val_loss: 0.0081
# Epoch 260/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0061 - val_loss: 0.0081
# Epoch 261/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0061 - val_loss: 0.0081
# Epoch 262/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0061 - val_loss: 0.0081
# Epoch 263/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0061 - val_loss: 0.0081
# Epoch 264/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0061 - val_loss: 0.0081
# Epoch 265/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0061 - val_loss: 0.0081
# Epoch 266/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0061 - val_loss: 0.0081
# Epoch 267/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0061 - val_loss: 0.0081
# Epoch 268/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0061 - val_loss: 0.0081
# Epoch 269/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - loss: 0.0061 - val_loss: 0.0081
# Epoch 270/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0061 - val_loss: 0.0081
# Epoch 271/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0061 - val_loss: 0.0081
# Epoch 272/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0061 - val_loss: 0.0081
# Epoch 273/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0061 - val_loss: 0.0080
# Epoch 274/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0061 - val_loss: 0.0080
# Epoch 275/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0061 - val_loss: 0.0080
# Epoch 276/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.0061 - val_loss: 0.0080
# Epoch 277/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.0061 - val_loss: 0.0080
# Epoch 278/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0061 - val_loss: 0.0080
# Epoch 279/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0061 - val_loss: 0.0080
# Epoch 280/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0061 - val_loss: 0.0080
# Epoch 281/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0060 - val_loss: 0.0080
# Epoch 282/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0060 - val_loss: 0.0080
# Epoch 283/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0060 - val_loss: 0.0080
# Epoch 284/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0060 - val_loss: 0.0080
# Epoch 285/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.0060 - val_loss: 0.0080
# Epoch 286/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0060 - val_loss: 0.0080
# Epoch 287/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0060 - val_loss: 0.0080
# Epoch 288/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0060 - val_loss: 0.0080
# Epoch 289/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0060 - val_loss: 0.0080
# Epoch 290/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0060 - val_loss: 0.0080
# Epoch 291/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.0060 - val_loss: 0.0080
# Epoch 292/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0060 - val_loss: 0.0080
# Epoch 293/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0060 - val_loss: 0.0080
# Epoch 294/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0060 - val_loss: 0.0080
# Epoch 295/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0060 - val_loss: 0.0080
# Epoch 296/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0060 - val_loss: 0.0080
# Epoch 297/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.0060 - val_loss: 0.0080
# Epoch 298/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0060 - val_loss: 0.0080
# Epoch 299/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 0.0060 - val_loss: 0.0080
# Epoch 300/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0060 - val_loss: 0.0080
# Epoch 301/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0060 - val_loss: 0.0080
# Epoch 302/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0060 - val_loss: 0.0080
# Epoch 303/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0060 - val_loss: 0.0080
# Epoch 304/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0060 - val_loss: 0.0080
# Epoch 305/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0060 - val_loss: 0.0080
# Epoch 306/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0060 - val_loss: 0.0080
# Epoch 307/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0060 - val_loss: 0.0080
# Epoch 308/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0060 - val_loss: 0.0079
# Epoch 309/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0060 - val_loss: 0.0079
# Epoch 310/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 0.0060 - val_loss: 0.0079
# Epoch 311/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0060 - val_loss: 0.0079
# Epoch 312/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0060 - val_loss: 0.0079
# Epoch 313/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0060 - val_loss: 0.0079
# Epoch 314/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0060 - val_loss: 0.0079
# Epoch 315/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0060 - val_loss: 0.0079
# Epoch 316/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0060 - val_loss: 0.0079
# Epoch 317/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0060 - val_loss: 0.0079
# Epoch 318/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0060 - val_loss: 0.0079
# Epoch 319/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0060 - val_loss: 0.0079
# Epoch 320/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.0059 - val_loss: 0.0079
# Epoch 321/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0059 - val_loss: 0.0079
# Epoch 322/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0059 - val_loss: 0.0079
# Epoch 323/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0059 - val_loss: 0.0079
# Epoch 324/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0059 - val_loss: 0.0079
# Epoch 325/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0059 - val_loss: 0.0079
# Epoch 326/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.0059 - val_loss: 0.0079
# Epoch 327/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0059 - val_loss: 0.0079
# Epoch 328/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0059 - val_loss: 0.0079
# Epoch 329/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0059 - val_loss: 0.0079
# Epoch 330/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0059 - val_loss: 0.0079
# Epoch 331/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0059 - val_loss: 0.0079
# Epoch 332/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0059 - val_loss: 0.0079
# Epoch 333/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0059 - val_loss: 0.0079
# Epoch 334/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0059 - val_loss: 0.0079
# Epoch 335/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0059 - val_loss: 0.0079
# Epoch 336/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0059 - val_loss: 0.0079
# Epoch 337/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0059 - val_loss: 0.0079
# Epoch 338/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0059 - val_loss: 0.0079
# Epoch 339/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0059 - val_loss: 0.0079
# Epoch 340/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0059 - val_loss: 0.0079
# Epoch 341/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0059 - val_loss: 0.0079
# Epoch 342/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0059 - val_loss: 0.0079
# Epoch 343/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0059 - val_loss: 0.0079
# Epoch 344/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0059 - val_loss: 0.0079
# Epoch 345/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0059 - val_loss: 0.0079
# Epoch 346/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0059 - val_loss: 0.0079
# Epoch 347/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0059 - val_loss: 0.0079
# Epoch 348/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0059 - val_loss: 0.0079
# Epoch 349/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0059 - val_loss: 0.0079
# Epoch 350/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0059 - val_loss: 0.0079
# Epoch 351/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0059 - val_loss: 0.0079
# Epoch 352/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0059 - val_loss: 0.0078
# Epoch 353/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0059 - val_loss: 0.0078
# Epoch 354/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0059 - val_loss: 0.0078
# Epoch 355/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0059 - val_loss: 0.0078
# Epoch 356/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0059 - val_loss: 0.0078
# Epoch 357/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0059 - val_loss: 0.0078
# Epoch 358/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0059 - val_loss: 0.0078
# Epoch 359/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0059 - val_loss: 0.0078
# Epoch 360/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0059 - val_loss: 0.0078
# Epoch 361/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0059 - val_loss: 0.0078
# Epoch 362/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0059 - val_loss: 0.0078
# Epoch 363/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0059 - val_loss: 0.0078
# Epoch 364/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0059 - val_loss: 0.0078
# Epoch 365/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0059 - val_loss: 0.0078
# Epoch 366/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0059 - val_loss: 0.0078
# Epoch 367/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0059 - val_loss: 0.0078
# Epoch 368/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0059 - val_loss: 0.0078
# Epoch 369/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0059 - val_loss: 0.0078
# Epoch 370/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0059 - val_loss: 0.0078
# Epoch 371/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0059 - val_loss: 0.0078
# Epoch 372/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0058 - val_loss: 0.0078
# Epoch 373/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0058 - val_loss: 0.0078
# Epoch 374/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0058 - val_loss: 0.0078
# Epoch 375/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0058 - val_loss: 0.0078
# Epoch 376/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0058 - val_loss: 0.0078
# Epoch 377/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0058 - val_loss: 0.0078
# Epoch 378/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0058 - val_loss: 0.0078
# Epoch 379/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0058 - val_loss: 0.0078
# Epoch 380/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0058 - val_loss: 0.0078
# Epoch 381/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.0058 - val_loss: 0.0078
# Epoch 382/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0058 - val_loss: 0.0078
# Epoch 383/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0058 - val_loss: 0.0078
# Epoch 384/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0058 - val_loss: 0.0078
# Epoch 385/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0058 - val_loss: 0.0078
# Epoch 386/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0058 - val_loss: 0.0078
# Epoch 387/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0058 - val_loss: 0.0078
# Epoch 388/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0058 - val_loss: 0.0078
# Epoch 389/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0058 - val_loss: 0.0078
# Epoch 390/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0058 - val_loss: 0.0078
# Epoch 391/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0058 - val_loss: 0.0078
# Epoch 392/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0058 - val_loss: 0.0078
# Epoch 393/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0058 - val_loss: 0.0078
# Epoch 394/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0058 - val_loss: 0.0078
# Epoch 395/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.0058 - val_loss: 0.0078
# Epoch 396/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0058 - val_loss: 0.0078
# Epoch 397/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0058 - val_loss: 0.0078
# Epoch 398/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0058 - val_loss: 0.0078
# Epoch 399/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0058 - val_loss: 0.0078
# Epoch 400/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0058 - val_loss: 0.0078
# Epoch 401/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.0058 - val_loss: 0.0078
# Epoch 402/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.0058 - val_loss: 0.0078
# Epoch 403/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0058 - val_loss: 0.0078
# Epoch 404/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 0.0058 - val_loss: 0.0078
# Epoch 405/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0058 - val_loss: 0.0078
# Epoch 406/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0058 - val_loss: 0.0078
# Epoch 407/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0058 - val_loss: 0.0078
# Epoch 408/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0058 - val_loss: 0.0078
# Epoch 409/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0058 - val_loss: 0.0078
# Epoch 410/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0058 - val_loss: 0.0077
# Epoch 411/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.0058 - val_loss: 0.0077
# Epoch 412/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0058 - val_loss: 0.0077
# Epoch 413/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0058 - val_loss: 0.0077
# Epoch 414/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0058 - val_loss: 0.0077
# Epoch 415/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0058 - val_loss: 0.0077
# Epoch 416/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0058 - val_loss: 0.0077
# Epoch 417/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - loss: 0.0058 - val_loss: 0.0077
# Epoch 418/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.0058 - val_loss: 0.0077
# Epoch 419/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0058 - val_loss: 0.0077
# Epoch 420/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0058 - val_loss: 0.0077
# Epoch 421/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0058 - val_loss: 0.0077
# Epoch 422/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0058 - val_loss: 0.0077
# Epoch 423/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0058 - val_loss: 0.0077
# Epoch 424/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0058 - val_loss: 0.0077
# Epoch 425/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0058 - val_loss: 0.0077
# Epoch 426/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0058 - val_loss: 0.0077
# Epoch 427/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.0058 - val_loss: 0.0077
# Epoch 428/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0058 - val_loss: 0.0077
# Epoch 429/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.0058 - val_loss: 0.0077
# Epoch 430/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0058 - val_loss: 0.0077
# Epoch 431/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0058 - val_loss: 0.0077
# Epoch 432/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0058 - val_loss: 0.0077
# Epoch 433/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0058 - val_loss: 0.0077
# Epoch 434/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0058 - val_loss: 0.0077
# Epoch 435/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0058 - val_loss: 0.0077
# Epoch 436/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0058 - val_loss: 0.0077
# Epoch 437/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0058 - val_loss: 0.0077
# Epoch 438/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0058 - val_loss: 0.0077
# Epoch 439/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0058 - val_loss: 0.0077
# Epoch 440/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.0058 - val_loss: 0.0077
# Epoch 441/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0057 - val_loss: 0.0077
# Epoch 442/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0057 - val_loss: 0.0077
# Epoch 443/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0057 - val_loss: 0.0077
# Epoch 444/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0057 - val_loss: 0.0077
# Epoch 445/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0057 - val_loss: 0.0077
# Epoch 446/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0057 - val_loss: 0.0077
# Epoch 447/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0057 - val_loss: 0.0077
# Epoch 448/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0057 - val_loss: 0.0077
# Epoch 449/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0057 - val_loss: 0.0077
# Epoch 450/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0057 - val_loss: 0.0077
# Epoch 451/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0057 - val_loss: 0.0077
# Epoch 452/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0057 - val_loss: 0.0077
# Epoch 453/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0057 - val_loss: 0.0077
# Epoch 454/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0057 - val_loss: 0.0077
# Epoch 455/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0057 - val_loss: 0.0077
# Epoch 456/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0057 - val_loss: 0.0077
# Epoch 457/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0057 - val_loss: 0.0077
# Epoch 458/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 0.0057 - val_loss: 0.0077
# Epoch 459/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0057 - val_loss: 0.0077
# Epoch 460/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0057 - val_loss: 0.0077
# Epoch 461/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0057 - val_loss: 0.0077
# Epoch 462/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0057 - val_loss: 0.0077
# Epoch 463/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0057 - val_loss: 0.0077
# Epoch 464/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0057 - val_loss: 0.0077
# Epoch 465/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0057 - val_loss: 0.0077
# Epoch 466/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0057 - val_loss: 0.0077
# Epoch 467/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0057 - val_loss: 0.0077
# Epoch 468/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.0057 - val_loss: 0.0077
# Epoch 469/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0057 - val_loss: 0.0077
# Epoch 470/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0057 - val_loss: 0.0077
# Epoch 471/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0057 - val_loss: 0.0077
# Epoch 472/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0057 - val_loss: 0.0077
# Epoch 473/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0057 - val_loss: 0.0077
# Epoch 474/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0057 - val_loss: 0.0077
# Epoch 475/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0057 - val_loss: 0.0077
# Epoch 476/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0057 - val_loss: 0.0077
# Epoch 477/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0057 - val_loss: 0.0077
# Epoch 478/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0057 - val_loss: 0.0077
# Epoch 479/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0057 - val_loss: 0.0077
# Epoch 480/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0057 - val_loss: 0.0077
# Epoch 481/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0057 - val_loss: 0.0077
# Epoch 482/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0057 - val_loss: 0.0077
# Epoch 483/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0057 - val_loss: 0.0077
# Epoch 484/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0057 - val_loss: 0.0077
# Epoch 485/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0057 - val_loss: 0.0077
# Epoch 486/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0057 - val_loss: 0.0076
# Epoch 487/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0057 - val_loss: 0.0076
# Epoch 488/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0057 - val_loss: 0.0076
# Epoch 489/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0057 - val_loss: 0.0076
# Epoch 490/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0057 - val_loss: 0.0076
# Epoch 491/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.0057 - val_loss: 0.0076
# Epoch 492/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0057 - val_loss: 0.0076
# Epoch 493/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.0057 - val_loss: 0.0076
# Epoch 494/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0057 - val_loss: 0.0076
# Epoch 495/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0057 - val_loss: 0.0076
# Epoch 496/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0057 - val_loss: 0.0076
# Epoch 497/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0057 - val_loss: 0.0076
# Epoch 498/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0057 - val_loss: 0.0076
# Epoch 499/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0057 - val_loss: 0.0076
# Epoch 500/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.0057 - val_loss: 0.0076
# Epoch 501/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0057 - val_loss: 0.0076
# Epoch 502/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0057 - val_loss: 0.0076
# Epoch 503/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0057 - val_loss: 0.0076
# Epoch 504/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0057 - val_loss: 0.0076
# Epoch 505/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0057 - val_loss: 0.0076
# Epoch 506/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0057 - val_loss: 0.0076
# Epoch 507/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0057 - val_loss: 0.0076
# Epoch 508/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0057 - val_loss: 0.0076
# Epoch 509/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0057 - val_loss: 0.0076
# Epoch 510/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0057 - val_loss: 0.0076
# Epoch 511/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0057 - val_loss: 0.0076
# Epoch 512/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0057 - val_loss: 0.0076
# Epoch 513/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0057 - val_loss: 0.0076
# Epoch 514/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0057 - val_loss: 0.0076
# Epoch 515/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0057 - val_loss: 0.0076
# Epoch 516/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0057 - val_loss: 0.0076
# Epoch 517/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0057 - val_loss: 0.0076
# Epoch 518/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0057 - val_loss: 0.0076
# Epoch 519/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0057 - val_loss: 0.0076
# Epoch 520/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0057 - val_loss: 0.0076
# Epoch 521/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0057 - val_loss: 0.0076
# Epoch 522/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0057 - val_loss: 0.0076
# Epoch 523/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0057 - val_loss: 0.0076
# Epoch 524/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0057 - val_loss: 0.0076
# Epoch 525/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0057 - val_loss: 0.0076
# Epoch 526/2000
# ...
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1676/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1677/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1678/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1679/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1680/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1681/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1682/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1683/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1684/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1685/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1686/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1687/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1688/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1689/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1690/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1691/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1692/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1693/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1694/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1695/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1696/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1697/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1698/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1699/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1700/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1701/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1702/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1703/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1704/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1705/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1706/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1707/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1708/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1709/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1710/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1711/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1712/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1713/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1714/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1715/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1716/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1717/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1718/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1719/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1720/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1721/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1722/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1723/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1724/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1725/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1726/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1727/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1728/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1729/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1730/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1731/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1732/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1733/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1734/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1735/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1736/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1737/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1738/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1739/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1740/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1741/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1742/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1743/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1744/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1745/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1746/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1747/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1748/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1749/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1750/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1751/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1752/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1753/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1754/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1755/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1756/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1757/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1758/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1759/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1760/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1761/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1762/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1763/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1764/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1765/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1766/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1767/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1768/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1769/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1770/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1771/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1772/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1773/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1774/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1775/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1776/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1777/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1778/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1779/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1780/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1781/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1782/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1783/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1784/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1785/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1786/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1787/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1788/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1789/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1790/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1791/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1792/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1793/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1794/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1795/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1796/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1797/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1798/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1799/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1800/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1801/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1802/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1803/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1804/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1805/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 1806/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0016 - val_loss: 0.0042
# Epoch 1807/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0016 - val_loss: 0.0042
# Epoch 1808/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0016 - val_loss: 0.0042
# Epoch 1809/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.0016 - val_loss: 0.0042
# Epoch 1810/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0016 - val_loss: 0.0042
# Epoch 1811/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0016 - val_loss: 0.0042
# Epoch 1812/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.0016 - val_loss: 0.0042
# Epoch 1813/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.0016 - val_loss: 0.0042
# Epoch 1814/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.0016 - val_loss: 0.0042
# Epoch 1815/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.0016 - val_loss: 0.0042
# Epoch 1816/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0016 - val_loss: 0.0042
# Epoch 1817/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0016 - val_loss: 0.0042
# Epoch 1818/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0016 - val_loss: 0.0042
# Epoch 1819/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.0016 - val_loss: 0.0042
# Epoch 1820/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0016 - val_loss: 0.0042
# Epoch 1821/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.0016 - val_loss: 0.0042
# Epoch 1822/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.0016 - val_loss: 0.0042
# Epoch 1823/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0016 - val_loss: 0.0042
# Epoch 1824/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.0016 - val_loss: 0.0042
# Epoch 1825/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0016 - val_loss: 0.0042
# Epoch 1826/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0016 - val_loss: 0.0042
# Epoch 1827/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0016 - val_loss: 0.0042
# Epoch 1828/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0016 - val_loss: 0.0042
# Epoch 1829/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.0016 - val_loss: 0.0042
# Epoch 1830/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0016 - val_loss: 0.0042
# Epoch 1831/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.0016 - val_loss: 0.0042
# Epoch 1832/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0016 - val_loss: 0.0042
# Epoch 1833/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.0016 - val_loss: 0.0042
# Epoch 1834/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0016 - val_loss: 0.0042
# Epoch 1835/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.0016 - val_loss: 0.0042
# Epoch 1836/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0016 - val_loss: 0.0042
# Epoch 1837/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0016 - val_loss: 0.0042
# Epoch 1838/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0016 - val_loss: 0.0042
# Epoch 1839/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.0016 - val_loss: 0.0042
# Epoch 1840/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0016 - val_loss: 0.0042
# Epoch 1841/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0016 - val_loss: 0.0042
# Epoch 1842/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.0016 - val_loss: 0.0042
# Epoch 1843/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0016 - val_loss: 0.0042
# Epoch 1844/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0016 - val_loss: 0.0042
# Epoch 1845/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0016 - val_loss: 0.0042
# Epoch 1846/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0016 - val_loss: 0.0042
# Epoch 1847/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0016 - val_loss: 0.0042
# Epoch 1848/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.0016 - val_loss: 0.0042
# Epoch 1849/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0016 - val_loss: 0.0042
# Epoch 1850/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0016 - val_loss: 0.0042
# Epoch 1851/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0016 - val_loss: 0.0042
# Epoch 1852/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0016 - val_loss: 0.0042
# Epoch 1853/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0016 - val_loss: 0.0042
# Epoch 1854/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0016 - val_loss: 0.0042
# Epoch 1855/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0016 - val_loss: 0.0042
# Epoch 1856/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.0016 - val_loss: 0.0042

# %% [markdown]
# ## Reconstruction on a Sample
#
# To qualitatively verify the training, we select a single validation sample and run the autoencoder to obtain its reconstruction.
# We then compute the reconstruction error (MSE) between the original input and the reconstructed output.

# %%
# -----------------------------
# Sample selection
# -----------------------------
idx = 31  # choose any index in the validation set
sample = x_val[idx]
sample_input = np.expand_dims(sample, axis=0)  # shape: (1, H, W, C)

# -----------------------------
# Reconstruction
# -----------------------------
recon = autoencoder.predict(sample_input, verbose=0)[0]

# -----------------------------
# Reconstruction Error (MSE)
# -----------------------------
mse = np.mean((sample - recon) ** 2)
print(f"Reconstruction MSE: {mse:.6f}")

label = y_val[idx]
print("Label:", "GOOD" if label == 0 else "BAD")

# -----------------------------
# Visualization: original vs reconstruction
# -----------------------------
fig, axs = plt.subplots(1, 2, figsize=(8, 4))

axs[0].imshow(sample)
axs[0].set_title("Original")
axs[0].axis("off")

axs[1].imshow(recon)
axs[1].set_title("Reconstruction")
axs[1].axis("off")

plt.tight_layout()
plt.show()
# Out:
# Reconstruction MSE: 0.005859
# Label: GOOD

# %% [markdown]
# ## Saving the Trained Model
#
# To enable reuse and reproducibility, we save the trained autoencoder to disk.
# The saved model can later be loaded for evaluation on anomalous data or for inference in other scripts.

# %%
MODEL_DIR = Path("../../models")
MODEL_DIR.mkdir(parents=True, exist_ok=True)

model_path = MODEL_DIR / "ae_bn16_bosch_dataset_M01_OP07_20260624.keras"

# -----------------------------
# Save the trained model
# -----------------------------
autoencoder.save(model_path)

print(f"Model saved to: {model_path}")
# Out:
# Model saved to: ..\models\ae_bn16_bosch_dataset_M01_OP07_20260624.keras

# %%
plt.figure(figsize=(10, 5))

plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')

plt.xlabel('Epoch')
plt.ylabel('MSE Loss')
plt.title('Reconstruction Error during Training')
plt.legend()
plt.tight_layout()
plt.show()

# %%
print("Final Train Loss:", history.history['loss'][-1])
print("Final Val Loss:", history.history['val_loss'][-1])
# Out:
# Final Train Loss: 0.0016214693896472454
# Final Val Loss: 0.0041788299567997456

# %% [markdown]
# # Reconstruction & Validation

# %%
recon_val = autoencoder.predict(x_val, batch_size=32, verbose=1)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step

# %%
val_errors = np.mean((x_val - recon_val)**2, axis=(1, 2, 3))
file_ids_val = [extract_file_id(p) for p in val_paths]

# %%
df_val = pd.DataFrame({
    "file_id": file_ids_val,
    "error": val_errors,
    "label": y_val
})

# %%
file_scores_val = []

for file_id, group in df_val.groupby("file_id"):

    label = group["label"].iloc[0]   # ✅ korrekt (File-Level Label)
    errors = group["error"].values

    score = np.max(errors)   # 🔥 wichtig!

    file_scores_val.append({
        "file_id": file_id,
        "label": label,
        "score": score
    })

file_val = pd.DataFrame(file_scores_val)

# %%
good_scores = file_val[file_val["label"] == 0]["score"]
bad_scores = file_val[file_val["label"] == 1]["score"]

plt.figure(figsize=(8,5))

plt.hist(good_scores, bins=10, alpha=0.5, label="GOOD")
plt.hist(bad_scores, bins=10, alpha=0.5, label="BAD")

plt.legend()
plt.title("Validation File-Level Scores")
plt.xlabel("Reconstruction Error")
plt.ylabel("Count")

plt.show()

# %%
from sklearn.metrics import precision_recall_curve

precision, recall, thresholds = precision_recall_curve(
    file_val["label"],
    file_val["score"]
)

f1 = 2 * precision[:-1] * recall[:-1] / (precision[:-1] + recall[:-1] + 1e-12)

best_idx = np.argmax(f1)
best_threshold = thresholds[best_idx]

print("Best threshold:", best_threshold)
# Out:
# Best threshold: 0.009010974

# %% [markdown]
# ### Reconstruction on Test Set

# %%
recon_test = autoencoder.predict(x_test, batch_size=32, verbose=1)
test_errors = np.mean((x_test - recon_test)**2, axis=(1, 2, 3))


file_ids_test = [extract_file_id(p) for p in test_paths]

df_test = pd.DataFrame({
    "file_id": file_ids_test,
    "error": test_errors,
    "label": y_test
})


file_scores_test = []

for file_id, group in df_test.groupby("file_id"):

    label = group["label"].iloc[0]
    errors = group["error"].values

    score = np.max(errors)

    file_scores_test.append({
        "file_id": file_id,
        "label": label,
        "score": score
    })

file_test = pd.DataFrame(file_scores_test)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step

# %%
from sklearn.metrics import roc_auc_score, average_precision_score

roc_auc = roc_auc_score(file_test["label"], file_test["score"])
pr_auc = average_precision_score(file_test["label"], file_test["score"])

print("ROC-AUC:", roc_auc)
print("PR-AUC:", pr_auc)
# Out:
# ROC-AUC: 1.0
# PR-AUC: 1.0

# %%
from sklearn.metrics import classification_report, confusion_matrix

y_pred = (file_test["score"] >= best_threshold).astype(int)

print(classification_report(file_test["label"], y_pred))
print(confusion_matrix(file_test["label"], y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         7
#            1       1.00      1.00      1.00         1
#
#     accuracy                           1.00         8
#    macro avg       1.00      1.00      1.00         8
# weighted avg       1.00      1.00      1.00         8
#
# [[7 0]
#  [0 1]]

# %%
def load_segments_from_file_id(file_id, file_to_paths):
    paths = sorted(file_to_paths[file_id])

    segments = []
    for p in paths:
        img = np.array(Image.open(p).convert("RGB")) / 255.0
        segments.append(img)

    return np.array(segments), paths


def plot_segments(original, recon, diff, errors, title="", max_cols=5):
    n = len(original)

    cols = max_cols
    rows = int(np.ceil(n / cols))

    fig, axes = plt.subplots(rows * 3, cols, figsize=(15, rows * 6))

    # Falls nur 1 Zeile → axes 2D machen
    axes = np.array(axes).reshape(rows * 3, cols)

    for i in range(n):
        r = i // cols
        c = i % cols

        # Original
        axes[r*3 + 0, c].imshow(original[i])
        axes[r*3 + 0, c].set_title(f"Orig {i}")
        axes[r*3 + 0, c].axis("off")

        # Rekonstruktion
        axes[r*3 + 1, c].imshow(recon[i])
        axes[r*3 + 1, c].set_title("Recon")
        axes[r*3 + 1, c].axis("off")

        # Differenz
        axes[r*3 + 2, c].imshow(diff[i], cmap="inferno")
        axes[r*3 + 2, c].set_title(f"MSE={errors[i]:.4f}")
        axes[r*3 + 2, c].axis("off")

    # leere Felder aus
    for j in range(n, rows * cols):
        for k in range(3):
            axes[(j // cols)*3 + k, j % cols].axis("off")

    plt.suptitle(title, fontsize=16)
    plt.tight_layout()
    plt.show()

def reconstruct_segments_tf(model, segments):
    """
    segments: numpy array (N, H, W, 3)
    """
    # Vorhersage
    recon = model.predict(segments, verbose=0)

    # Differenzbild (pixelweise)
    diff = np.abs(segments - recon)

    # MSE pro Segment
    errors = np.mean((segments - recon) ** 2, axis=(1, 2, 3))

    return recon, diff, errors

# %%
# z.B. erstes File aus Test-Set
good_id = test_files[0]

segments_good, paths_good = load_segments_from_file_id(good_id, file_to_paths)

print("GOOD segments shape:", segments_good.shape)


bad_id = bad_test_files[1]

segments_bad, paths_bad = load_segments_from_file_id(bad_id, bad_file_to_paths)

print("BAD segments shape:", segments_bad.shape)
# Out:
# GOOD segments shape: (5, 100, 150, 3)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[43], line 9
#       5
#       6 print("GOOD segments shape:", segments_good.shape)
#       7
#       8
# ----> 9 bad_id = bad_test_files[1]
#      10
#      11 segments_bad, paths_bad = load_segments_from_file_id(bad_id, bad_file_to_paths)
#      12
#
# IndexError: list index out of range

# %%
recon_good, diff_good, err_good = reconstruct_segments_tf(autoencoder, segments_good)

print("GOOD mean:", err_good.mean(), "max:", err_good.max())

plot_segments(
    segments_good,
    recon_good,
    diff_good,
    err_good,
    title=f"GOOD file: {good_id}"
)
# Out:
# GOOD mean: 0.00236817917900566 max: 0.0027682681651309787

# %%
recon_bad, diff_bad, err_bad = reconstruct_segments_tf(autoencoder, segments_bad)

print("BAD mean:", err_bad.mean(), "max:", err_bad.max())

plot_segments(
    segments_bad,
    recon_bad,
    diff_bad,
    err_bad,
    title=f"BAD file: {bad_id}"
)
# Out:
# BAD mean: 0.01877578780739959 max: 0.02096711875295757
